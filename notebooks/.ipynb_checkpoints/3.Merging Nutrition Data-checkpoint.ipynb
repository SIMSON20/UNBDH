# %% [markdown]
# ## Libraries

# %%
import os 
import numpy as np 
import pandas as pd 

from tqdm import tqdm
import warnings

warnings.filterwarnings("ignore")

# %%
sorted(os.listdir("../data/nutrients/"))
# Out:
# ['cassava_raw.csv',
#  'chicken_raw_meat_only_stewing.csv',
#  'corn_raw.csv',
#  'corn_raw_yellow_sweet.csv',
#  'cowpeas_raw_mature_seeds_catjang.csv',
#  'eggplant_raw.csv',
#  'fish_raw_atlantic_mackerel.csv',
#  'gari_by_golden_tropics_ltd.csv',
#  'millet_raw.csv',
#  'onions_raw.csv',
#  'peppers_dried_ancho.csv',
#  'peppers_raw_red_sweet.csv',
#  'plantains_raw_green.csv',
#  'rice_raw_longgrain_brown.csv',
#  'sorghum_grain.csv',
#  'sources.txt',
#  'soybeans_raw_mature_seeds.csv',
#  'tomatoes_raw.csv',
#  'yam_raw.csv']

# %% [markdown]
# ## Reading Data and Filtering Nutrients

# %%
def read_data(file_name):
    df = pd.read_csv(f"../data/nutrients/{file_name}", skiprows=6, skipfooter=5)
    df = df.loc[df.Nutrient.isin(nutrients)]
    df["commodity"] = file_name.split(".")[0]
    return df

# %%
nutrients = ["Calories", "Protein", "Calcium", "Iron", "Vitamin A, RAE", "Thiamin [Vitamin B1]", "Riboflavin [Vitamin B2]", "Niacin [Vitamin B3]", "Vitamin C [Ascorbic acid]"]

# %%
nutrients
# Out:
# ['Calories',
#  'Protein',
#  'Calcium',
#  'Iron',
#  'Vitamin A, RAE',
#  'Thiamin [Vitamin B1]',
#  'Riboflavin [Vitamin B2]',
#  'Niacin [Vitamin B3]',
#  'Vitamin C [Ascorbic acid]']

# %%
corn_raw = pd.read_csv("../data/nutrients/corn_raw.csv", skiprows=6, skipfooter=5)

# %%
corn_raw = corn_raw.loc[corn_raw.Nutrient.isin(nutrients)]

# %%
corn_raw
# Out:
#                      Nutrient  Amount Unit    DV
# 0                    Calories  86.000  NaN   NaN
# 1              Vitamin A, RAE   9.000  mcg   1 %
# 8        Thiamin [Vitamin B1]   0.155   mg  13 %
# 9     Riboflavin [Vitamin B2]   0.055   mg   4 %
# 10        Niacin [Vitamin B3]   1.770   mg  11 %
# 17  Vitamin C [Ascorbic acid]   6.800   mg   8 %
# 25                    Calcium   2.000   mg   0 %
# 27                       Iron   0.520   mg   3 %
# 34                    Protein   3.270    g   7 %

# %%
commodities_nutrients = pd.concat([read_data(f) for f in sorted(os.listdir("../data/nutrients/")) if f.endswith("csv")])

# %%
commodities_nutrients
# Out:
#                      Nutrient Amount Unit    DV    commodity
# 0                    Calories  160.0  NaN   NaN  cassava_raw
# 1              Vitamin A, RAE    1.0  mcg   0 %  cassava_raw
# 8        Thiamin [Vitamin B1]  0.087   mg   7 %  cassava_raw
# 9     Riboflavin [Vitamin B2]  0.048   mg   4 %  cassava_raw
# 10        Niacin [Vitamin B3]  0.854   mg   5 %  cassava_raw
# ..                        ...    ...  ...   ...          ...
# 10        Niacin [Vitamin B3]  0.552   mg   3 %      yam_raw
# 18  Vitamin C [Ascorbic acid]   17.1   mg  19 %      yam_raw
# 26                    Calcium   17.0   mg   1 %      yam_raw
# 28                       Iron   0.54   mg   3 %      yam_raw
# 36                    Protein   1.53    g   3 %      yam_raw
#
# [157 rows x 5 columns]

# %% [markdown]
# ## Saving Data

# %%
commodities_nutrients.to_csv("../data/commodities_nutrients.csv", index=False)

# %%
# pd.read_csv("../data/commodities_gha_nutrients.csv")
# Out:
#                  commodity  price  Calcium  Calories   Iron  \
# 0                  Cassava  0.652     16.0     160.0   0.27
# 1                     Gari  0.396     71.0     357.0   2.57
# 2                    Maize  0.456      2.0      86.0   0.52
# 3           Maize (yellow)  0.491      2.0      86.0   0.52
# 4                   Millet  0.651      8.0     378.0   3.01
# 5          Rice (imported)  1.000      9.0     367.0   1.29
# 6             Rice (local)  1.267      9.0     367.0   1.29
# 7                  Sorghum  0.667     13.0     329.0   3.36
# 8                      Yam  0.605     17.0     118.0   0.54
# 9               Yam (puna)  0.646     17.0     118.0   0.54
# 10  Fish (mackerel, fresh)  1.117     12.0     205.0   1.63
# 11          Meat (chicken)  0.988     10.0     148.0   1.09
# 12                 Cowpeas  0.394     85.0     343.0   9.95
# 13                Soybeans  1.177    277.0     446.0  15.70
# 14               Eggplants  0.405      9.0      25.0   0.23
# 15                  Onions  0.561     23.0      40.0   0.21
# 16         Peppers (dried)  0.240     61.0     281.0  10.93
# 17         Peppers (fresh)  0.580      7.0      26.0   0.43
# 18        Plantains (apem)  0.502      2.0     152.0   0.75
# 19      Plantains (apentu)  0.484      2.0     152.0   0.75
# 20        Tomatoes (local)  0.669     10.0      18.0   0.27
# 21     Tomatoes (navrongo)  0.305     10.0      18.0   0.27
#
#     Niacin [Vitamin B3]  Protein  Riboflavin [Vitamin B2]  \
# 0                 0.854     1.36                    0.048
# 1                 0.000     0.00                    0.000
# 2                 1.770     3.27                    0.055
# 3                 1.770     3.27                    0.055
# 4                 4.720    11.02                    0.290
# 5                 6.494     7.54                    0.095
# 6                 6.494     7.54                    0.095
# 7                 3.688    10.62                    0.096
# 8                 0.552     1.53                    0.032
# 9                 0.552     1.53                    0.032
# 10                9.080    18.60                    0.312
# 11                7.477    21.26                    0.207
# 12                2.795    23.85                    0.170
# 13                1.623    36.49                    0.870
# 14                0.649     0.98                    0.037
# 15                0.116     1.10                    0.027
# 16                6.403    11.86                    2.255
# 17                0.979     0.99                    0.085
# 18                0.550     1.25                    0.100
# 19                0.550     1.25                    0.100
# 20                0.594     0.88                    0.019
# 21                0.594     0.88                    0.019
#
#     Thiamin [Vitamin B1]  Vitamin C [Ascorbic acid]
# 0                  0.087                       20.6
# 1                  0.000                        0.0
# 2                  0.155                        6.8
# 3                  0.155                        6.8
# 4                  0.421                        0.0
# 5                  0.541                        0.0
# 6                  0.541                        0.0
# 7                  0.332                        0.0
# 8                  0.112                       17.1
# 9                  0.112                       17.1
# 10                 0.176                        0.4
# 11                 0.149                        3.3
# 12                 0.680                        1.5
# 13                 0.874                        6.0
# 14                 0.039                        2.2
# 15                 0.046                        7.4
# 16                 0.179                        2.0
# 17                 0.054                      127.7
# 18                 0.100                       20.2
# 19                 0.100                       20.2
# 20                 0.037                       13.7
# 21                 0.037                       13.7
